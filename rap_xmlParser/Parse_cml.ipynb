# %%
import xmltodict
import json

# %%
with open('rap_xml.xml', 'r') as file:
    data = file.read().replace('\n', '')

# %%
rap_dict = xmltodict.parse(data)
print(json.dumps(rap_dict, indent=4))
# Out:
# {
#     "score-partwise": {
#         "@version": "2.0",
#         "movement-title": "Booba-E.L.E.P.H.A.N.T",
#         "identification": {
#             "encoding": {
#                 "software": "Logic Pro",
#                 "encoding-date": "2020-03-28",
#                 "supports": [
#                     {
#                         "@attribute": "new-system",
#                         "@element": "print",
#                         "@type": "yes",
#                         "@value": "yes"
#                     },
#                     {
#                         "@attribute": "new-page",
#                         "@element": "print",
#                         "@type": "yes",
#                         "@value": "yes"
#                     }
#                 ]
#             }
#         },
#         "defaults": {
#             "scaling": {
#                 "millimeters": "7.540625",
#                 "tenths": "40"
#             },
#             "page-layout": {
# ...
